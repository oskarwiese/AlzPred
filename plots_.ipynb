# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
file = '/home/oskar/Hentet/ADNI1_Screening_1.5T_1_01_2022.csv'

# %%
df = pd.read_csv(file)

# %%
df.Age.value_counts().sort_index().plot.bar(figsize=(10,5))
plt.title('Histogram of Age')
plt.ylabel('Number of Subjects')
plt.xlabel('Age')
plt.savefig('/home/oskar/Dokumenter/sem7/AlzPred/reports/imgs/age_distro.png')

# %%
df.Age.mean()
# Out:
# 75.22325581395349
